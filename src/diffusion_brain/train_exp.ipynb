# %%
# %run scripts/train.py --config configs/mnist/config_train.yaml
# Out:
# wandb: Currently logged in as: arishka (3rd_year_project) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/belova/Desktop/diffusion_brain_alignment/wandb/run-20251117_144231-ao5hjzmt-g-None</code>
# Syncing run <strong><a href='https://wandb.ai/3rd_year_project/conditional-diffusion-mnist/runs/ao5hjzmt-g-None' target="_blank">ao5hjzmt-g-None</a></strong> to <a href='https://wandb.ai/3rd_year_project/conditional-diffusion-mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/3rd_year_project/conditional-diffusion-mnist' target="_blank">https://wandb.ai/3rd_year_project/conditional-diffusion-mnist</a>
# ...
